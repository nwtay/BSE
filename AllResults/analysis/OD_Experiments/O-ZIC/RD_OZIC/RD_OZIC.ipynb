# %% [markdown]
# Results for RD model with O-ZIC traders

# %% [markdown]
# # Experiment 1
#
# Parameters = (0.1, 0.2, 2, 0, 0.1)

# %% [markdown]
# ## Opinion Spread

# %%
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm, colors
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import csv
from collections import defaultdict, Counter
from matplotlib.pyplot import *
import matplotlib.colors
from matplotlib.animation import FuncAnimation

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('OZZICY_ops.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/opinionsRD_OZIC_1.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/opinionsRD_OZIC_1.pdf',dpi=200,bbox_inches='tight',pad_inches=0)

plt.show()
# Out:
# <ipython-input-5-2e7aef76af0c>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Transaction Spread

# %%
n_trials = 15
time_period = 225
transactions = []

with open('OZICCY_trans.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    previous_time = 0
    trial_count = 0
    for row in readCSV:
        if float(row[0]) >= previous_time:
            transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
        else:
            trial_count += 1
        previous_time = float(row[0])

time = np.array(transactions)[:,0]
price = np.array(transactions)[:,1]
  

# nums = np.arange(0, 600, 100)

print("Number of transactions:",len(price))

plt.figure(1, figsize=(10,10))
xlabel('Time', fontsize=30, labelpad=50)
ylabel('Price', fontsize=30, labelpad=30)
title("Transactions", fontsize=30)
# p1 = scatter(time, price, marker='x', color='red')
p1 = plot(time, price, 'orange', linewidth=3)
# p1 = plot(trials[i], 'green', linewidth=3)
p1 = plot()
ax = axes()
ax.set_facecolor('black')
# ylim(ymin=min(price)-20, ymax=max(price)+20)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=max(time)+20)
yticks(fontsize=30)
xticks(fontsize=30, rotation=270)
grid(linestyle='-', linewidth=1)

plt.savefig('Graphs/transactionsRD_OZIC_1.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/transactionsRD_OZIC_1.pdf',dpi=200,bbox_inches='tight',pad_inches=0)

show()
# Out:
# Number of transactions: 763
# <ipython-input-6-7558999ce92a>:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = axes()

# %% [markdown]
# # Experiment 2
#
# Parameters = (0.2, 0.2, 2, 0.1, 0.1)

# %% [markdown]
# ## Opinion Spread

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('opinionsRD_OZIC_2.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/opinionsRD_OZIC_2.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/opinionsRD_OZIC_2.pdf',dpi=200,bbox_inches='tight',pad_inches=0)

plt.show()
# Out:
# <ipython-input-5-93a2886cfc17>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Transaction Spread

# %%
n_trials = 15
time_period = 225
transactions = []

with open('transactionsRD_OZIC_2.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    previous_time = 0
    trial_count = 0
    for row in readCSV:
        if float(row[0]) >= previous_time:
            transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
        else:
            trial_count += 1
        previous_time = float(row[0])

time = np.array(transactions)[:,0]
price = np.array(transactions)[:,1]
  

# nums = np.arange(0, 600, 100)

print("Number of transactions:",len(price))

plt.figure(1, figsize=(10,10))
xlabel('Time', fontsize=30, labelpad=50)
ylabel('Price', fontsize=30, labelpad=30)
title("Transactions", fontsize=30)
# p1 = scatter(time, price, marker='x', color='red')
p1 = plot(time, price, 'orange', linewidth=3)
# p1 = plot(trials[i], 'green', linewidth=3)
p1 = plot()
ax = axes()
ax.set_facecolor('black')
# ylim(ymin=min(price)-20, ymax=max(price)+20)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=max(time)+20)
yticks(fontsize=30)
xticks(fontsize=30, rotation=270)
grid(linestyle='-', linewidth=1)

plt.savefig('Graphs/transactionsRD_OZIC_2.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/transactionsRD_OZIC_2.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


show()
# Out:
# Number of transactions: 1179
# <ipython-input-6-c6ab224fe3da>:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = axes()

# %% [markdown]
# # Experiment 3
#
# Parameters = (0.4, 0.2, 2, 0.4, 0.1)

# %% [markdown]
# ## Opinion Spread

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('opinionsRD_OZIC_3.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/opinionsRD_OZIC_3.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/opinionsRD_OZIC_3.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


plt.show()
# Out:
# <ipython-input-7-94ff7eb22c4f>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Transaction Spread

# %%
n_trials = 15
time_period = 225
transactions = []

with open('transactionsRD_OZIC_3.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    previous_time = 0
    trial_count = 0
    for row in readCSV:
        if float(row[0]) >= previous_time:
            transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
        else:
            trial_count += 1
        previous_time = float(row[0])

time = np.array(transactions)[:,0]
price = np.array(transactions)[:,1]
  

# nums = np.arange(0, 600, 100)

print("Number of transactions:",len(price))

plt.figure(1, figsize=(10,10))
xlabel('Time', fontsize=30, labelpad=50)
ylabel('Price', fontsize=30, labelpad=30)
title("Transactions", fontsize=30)
# p1 = scatter(time, price, marker='x', color='red')
p1 = plot(time, price, 'orange', linewidth=3)
# p1 = plot(trials[i], 'green', linewidth=3)
p1 = plot()
ax = axes()
ax.set_facecolor('black')
# ylim(ymin=min(price)-20, ymax=max(price)+20)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=max(time)+20)
yticks(fontsize=30)
xticks(fontsize=30, rotation=270)
grid(linestyle='-', linewidth=1)

plt.savefig('Graphs/transactionsRD_OZIC_3.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/transactionsRD_OZIC_3.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


show()
# Out:
# Number of transactions: 1358
# <ipython-input-9-4fbe3a530abc>:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = axes()

# %% [markdown]
# # Individual Sessions

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('opinionsRD_OZIC_1_session1.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ' and opinion != '':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/ops_sess1.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/ops_sess1.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


plt.show()
# Out:
# <ipython-input-10-4d6c0aaa09ed>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('opinionsRD_OZIC_2_session1.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ' and opinion != '':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/ops_sess2.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/ops_sess2.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


plt.show()
# Out:
# <ipython-input-12-098f1fe9cf7d>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('opinionsRD_OZIC_3_session1.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ' and opinion != '':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/ops_sess3.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/ops_sess3.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


plt.show()
# Out:
# <ipython-input-13-b8ebca470ba8>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()
