# %% [markdown]
# Results for BC model with O-PRZI traders

# %% [markdown]
# # Experiment 1
#
# Parameters = (0.01, 0.01)

# %% [markdown]
# ## Opinion Spread

# %%
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm, colors
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import csv
from collections import defaultdict, Counter
from matplotlib.pyplot import *
import matplotlib.colors
from matplotlib.animation import FuncAnimation

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('opinionsBC_OPRZI_1.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/opinionsBC_OPRZI_1.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/opinionsBC_OPRZI_1.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


plt.show()
# Out:
# <ipython-input-3-a49d138aa901>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Transaction Spread

# %%
n_trials = 15
time_period = 225
transactions = []

with open('transactionsBC_OPRZI_1.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    previous_time = 0
    trial_count = 0
    for row in readCSV:
        if float(row[0]) >= previous_time:
            transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
        else:
            trial_count += 1
        previous_time = float(row[0])

time = np.array(transactions)[:,0]
price = np.array(transactions)[:,1]
  

# nums = np.arange(0, 600, 100)

print("Number of transactions:",len(price))

plt.figure(1, figsize=(10,10))
xlabel('Time', fontsize=30, labelpad=50)
ylabel('Price', fontsize=30, labelpad=30)
title("Transactions", fontsize=30)
# p1 = scatter(time, price, marker='x', color='red')
p1 = plot(time, price, 'orange', linewidth=3)
# p1 = plot(trials[i], 'green', linewidth=3)
p1 = plot()
ax = axes()
ax.set_facecolor('black')
# ylim(ymin=min(price)-20, ymax=max(price)+20)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=max(time)+20)
yticks(fontsize=30)
xticks(fontsize=30, rotation=270)
grid(linestyle='-', linewidth=1)

plt.savefig('Graphs/transactionsBC_OPRZI_1.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/transactionsBC_OPRZI_1.pdf',dpi=200,bbox_inches='tight',pad_inches=0)

show()
# Out:
# Number of transactions: 4898
# <ipython-input-4-43559d4d484b>:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = axes()

# %% [markdown]
# # Experiment 2
#
# Parameters = (0.15, 0.15)

# %% [markdown]
# ## Opinion Spread

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('opinionsBC_OPRZI_2.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/opinionsBC_OPRZI_2.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/opinionsBC_OPRZI_2.pdf',dpi=200,bbox_inches='tight',pad_inches=0)

plt.show()
# Out:
# <ipython-input-5-2d8fde1a7842>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Transaction Spread

# %%
n_trials = 15
time_period = 225
transactions = []

with open('transactionsBC_OPRZI_2.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    previous_time = 0
    trial_count = 0
    for row in readCSV:
        if float(row[0]) >= previous_time:
            transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
        else:
            trial_count += 1
        previous_time = float(row[0])

time = np.array(transactions)[:,0]
price = np.array(transactions)[:,1]
  

# nums = np.arange(0, 600, 100)

print("Number of transactions:",len(price))

plt.figure(1, figsize=(10,10))
xlabel('Time', fontsize=30, labelpad=50)
ylabel('Price', fontsize=30, labelpad=30)
title("Transactions", fontsize=30)
# p1 = scatter(time, price, marker='x', color='red')
p1 = plot(time, price, 'orange', linewidth=3)
# p1 = plot(trials[i], 'green', linewidth=3)
p1 = plot()
ax = axes()
ax.set_facecolor('black')
# ylim(ymin=min(price)-20, ymax=max(price)+20)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=max(time)+20)
yticks(fontsize=30)
xticks(fontsize=30, rotation=270)
grid(linestyle='-', linewidth=1)

plt.savefig('Graphs/transactionsBC_OPRZI_2.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/transactionsBC_OPRZI_2.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


show()
# Out:
# Number of transactions: 4814
# <ipython-input-6-607fa2cbdf73>:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = axes()

# %% [markdown]
# # Experiment 3
#
# Parameters = (0.25, 0.25)

# %% [markdown]
# ## Opinion Spread

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('opinionsBC_OPRZI_3.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/opinionsBC_OPRZI_3.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/opinionsBC_OPRZI_3.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


plt.show()
# Out:
# <ipython-input-7-4548477d5a41>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Transaction Spread

# %%
n_trials = 15
time_period = 225
transactions = []

with open('transactionsBC_OPRZI_3.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    previous_time = 0
    trial_count = 0
    for row in readCSV:
        if float(row[0]) >= previous_time:
            transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
        else:
            trial_count += 1
        previous_time = float(row[0])

time = np.array(transactions)[:,0]
price = np.array(transactions)[:,1]
  

# nums = np.arange(0, 600, 100)

print("Number of transactions:",len(price))

plt.figure(1, figsize=(10,10))
xlabel('Time', fontsize=30, labelpad=50)
ylabel('Price', fontsize=30, labelpad=30)
title("Transactions", fontsize=30)
# p1 = scatter(time, price, marker='x', color='red')
p1 = plot(time, price, 'orange', linewidth=3)
# p1 = plot(trials[i], 'green', linewidth=3)
p1 = plot()
ax = axes()
ax.set_facecolor('black')
# ylim(ymin=min(price)-20, ymax=max(price)+20)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=max(time)+20)
yticks(fontsize=30)
xticks(fontsize=30, rotation=270)
grid(linestyle='-', linewidth=1)

plt.savefig('Graphs/transactionsBC_OPRZI_3.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/transactionsBC_OPRZI_3.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


show()
# Out:
# Number of transactions: 4852
# <ipython-input-9-337a9531557a>:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = axes()

# %%
opinionsBC_OPRZI_1_session1.csv

# %% [markdown]
# # Individiual Sessions

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('ops_sess1.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/ops_sess1.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/ops_sess1.pdf',dpi=200,bbox_inches='tight',pad_inches=0)


plt.show()
# Out:
# <ipython-input-13-a676b975df85>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('ops_sess2.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/ops_sess2.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/ops_sess2.pdf',dpi=200,bbox_inches='tight',pad_inches=0)

plt.show()
# Out:
# <ipython-input-14-02a1ad86e679>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('ops_sess3.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)

plt.savefig('Graphs/ops_sess3.png',dpi=200,bbox_inches='tight',pad_inches=0)
plt.savefig('Graphs/ops_sess3.pdf',dpi=200,bbox_inches='tight',pad_inches=0)

plt.show()
# Out:
# <ipython-input-15-80ae4c23a35d>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %%
n_trials = 1
time_period = 225
transactions = []

with open('../../transactionsBC_OZIC_1.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    previous_time = 0
    trial_count = 0
    for row in readCSV:
        if float(row[0]) >= previous_time:
            transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
        else:
            trial_count += 1
        previous_time = float(row[0])

time = np.array(transactions)[:,0]
print(time)
exit()
price = np.array(transactions)[:,1]
  

# nums = np.arange(0, 600, 100)

print("Number of transactions:",len(price))

plt.figure(1, figsize=(10,10))
xlabel('Time', fontsize=30, labelpad=50)
ylabel('Price', fontsize=30, labelpad=30)
title("Transactions", fontsize=30)
# p1 = scatter(time, price, marker='x', color='red')
p1 = plot(time, price, 'orange', linewidth=3)
# p1 = plot(trials[i], 'green', linewidth=3)
p1 = plot()
ax = axes()
ax.set_facecolor('black')
# ylim(ymin=min(price)-20, ymax=max(price)+20)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=max(time)+20)
yticks(fontsize=30)
xticks(fontsize=30, rotation=270)
grid(linestyle='-', linewidth=1)
show()
# Out:
# [  30.32    30.4     35.46    36.615   38.525   41.64    49.67    60.825
#    60.95    61.58    62.36    66.145   66.93    93.675   94.51    97.905
#    99.215  100.865  120.61   124.58   125.01   127.09   134.25   149.89
#   150.78   153.335  153.475  163.85   169.46   170.29   178.95   181.33
#   182.5    184.86   185.43   187.87   191.47   211.425  212.835  214.795
#   215.795  221.29   257.315  281.035  289.74   295.965  304.98   305.065
#   312.825  315.85   318.19   330.105  331.475  347.64   349.145  350.58
#   352.945  353.165  375.92   378.665  384.405  387.345  388.08   407.8
#   414.11   417.415  420.865  435.735  445.815  448.765  483.49   483.975
#   484.02   485.325  486.64   494.83   494.875  510.125  510.465  511.35
#   511.5    513.22   514.47   515.66   515.68   522.775  540.175  541.11
#   543.105  546.06   546.16   547.555  547.8    550.24   560.76   570.275
#   570.375  573.87   575.435  576.925  581.855  583.775  587.085  600.025
#   600.17   600.24   601.435  603.63   603.735  604.085  604.675  605.54
#   624.925  631.175  631.395  631.94   632.61   632.685  633.49   635.41
#   637.005  656.91   660.325  660.755  662.985  663.205  663.275  665.26
#   665.61   666.655  670.6    673.96   707.8    707.92   708.25   712.185
#   716.295  718.79   719.025  720.26   723.835  735.745  736.67   737.825
#   739.625  741.105  741.415  746.365  748.385  760.955  767.1    768.595
#   768.83   770.435  770.715  771.885  772.905  774.05   780.765  783.84
#   795.84   796.655  801.565  802.44   811.735  819.87   825.165  825.625
#   827.95   830.02   838.72   839.135  840.07   840.485  855.375  855.655
#   855.92   856.82   859.05   860.535  861.155  863.95   874.725  885.415
#   885.695  886.89   887.83   891.12   894.365  897.445  936.58   939.62
#   940.22   943.675  952.625  961.105  962.34   964.14   964.24   964.615
#   966.285  976.725  990.8    990.9    991.395  992.04  1000.095 1003.035
#  1006.33  1020.49  1021.48  1021.735 1022.13  1024.44  1025.41  1033.57
#  1034.05  1047.35  1049.435 1050.635 1050.86  1050.975 1052.27  1052.445
#  1056.5   1058.89  1066.105 1080.895 1082.52  1085.135 1088.92  1090.865
#  1093.18  1099.395 1102.86  1103.425 1110.475 1114.39  1115.855 1117.135
#  1119.85  1158.98  1160.06  1166.305 1167.64  1183.38  1185.55  1185.695
#  2541.91  2544.79  2545.75  2572.035 2574.825 2577.465 2582.94  2588.16
#  2589.975 2598.835 2599.46  2606.625 2611.705 2626.485 2629.905 2636.355
#  2636.895 2641.325 2644.55  2657.94  2660.585 2660.625 2665.265 2672.725
#  2685.835 2687.315 2689.    2696.39  2737.53  2738.625 2742.605 2743.785
#  2759.035 2762.025 2762.86  2766.01  2769.62  2774.495 2783.16  2791.805
#  2793.11  2793.315 2794.24  2794.59  2807.575 2807.605 2821.495 2829.495
#  2830.945 2836.54  2837.01  2839.67  2847.135 2853.51  2854.9   2857.925
#  2862.565 2864.75  2867.475 2881.91  2883.15  2885.38  2887.125 2890.885
#  2903.04  2903.21  2914.88  2918.54  2923.55  2958.33  2961.085 2964.73
#  2970.155 2984.105 2985.195 2985.85  2986.62  2988.13  2991.725 2993.515
#  3011.835 3015.615 3016.095 3017.98  3020.275 3025.74  3026.955 3045.61
#  3048.35  3051.825 3055.455 3067.095 3071.615 3075.69  3076.025 3080.935
#  3081.815 3106.225 3107.265 3108.205 3116.295 3133.69  3135.77  3135.87
#  3139.08  3140.1   3143.84  3146.56  3148.22  3185.14  3189.17  3195.865
#  3197.49  3213.015 3216.645 3218.525 3226.87  3233.915 3240.97  3241.38
#  3245.28  3267.57  3271.425 3275.8   3286.97  3302.81  3310.76  3316.355
#  3316.835 3331.35  3336.72  3338.56  3344.625 3346.74  3349.755 3351.865
#  3352.06  3360.705 3363.65  3366.64  3368.205 3371.015]
# Number of transactions: 662
# <ipython-input-3-53efe97b7c1e>:34: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = axes()

# %%
step = []
opinions = []
cs = []

# model_name = 'BC'

with open('../../opinionsBC_OPRZI_4.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    trial_count = 0
    time_period = 225
    for row in readCSV:
        trial_count = int(row[0][5:])
        ntime=row[1]
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append((trial_count-1)* time_period + float(ntime))
                
#     previous_time = 0
#     trial_count = 0
#     for row in readCSV:
#         if float(row[0]) >= previous_time:
#             transactions.append([((trial_count * time_period) + float(row[0])), float(row[1])])
#         else:
#             trial_count += 1
#         previous_time = float(row[0])
                
fig = plt.figure(3, figsize=(10,10))
plt.xlabel('Time', fontsize=30, labelpad=50)
plt.ylabel('Opinion', fontsize=30, labelpad=30)
# plt.title(model_name +" w=0.12", fontsize=30)
# p3 = scatter(step, smiddle, step, slower, step, supper)
ax=plt.axes()
ax.set_facecolor('black')
p3 = plt.scatter(step, opinions, color='orange')
# plt.xlim(xmin=0, xmax=180)
plt.ylim(ymin=-1, ymax=1)
plt.yticks(fontsize=24)
plt.xticks(fontsize=24, rotation=270)
plt.show()
# Out:
# <ipython-input-16-a2c3a6c664d4>:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()
